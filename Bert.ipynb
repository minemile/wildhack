# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Model

# %%
from transformers import AutoTokenizer, AutoModelForPreTraining
  
tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny")

model = AutoModelForPreTraining.from_pretrained("cointegrated/rubert-tiny")
# Out:
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/632 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/235k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/457k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/45.5M [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipeline_fill_mask = pipeline("fill-mask", model=model, tokenizer=tokenizer)

# %%
text = "пуховик женский [MASK]"

# %%
pipeline_fill_mask(text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_b/wr14ty5d1q96p67h9t1csd8w0000gn/T/ipykernel_33428/746056690.py in <module>
# ----> 1 pipeline_fill_mask(text)
#
# ~/anaconda3/envs/wildhack/lib/python3.7/site-packages/transformers/pipelines/fill_mask.py in __call__(self, inputs, *args, **kwargs)
#     220             - **token** (:obj:`str`) -- The predicted token (to replace the masked one).
#     221         """
# --> 222         outputs = super().__call__(inputs, **kwargs)
#     223         if isinstance(inputs, list) and len(inputs) == 1:
#     224             return outputs[0]
#
# ~/anaconda3/envs/wildhack/lib/python3.7/site-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, *args, **kwargs)
#     922             return self.get_iterator(inputs, num_workers, preprocess_params, forward_params, postprocess_params)
# ...

# %%
text = "пуховик женский [MASK]"
encoded_input = tokenizer(text, return_tensors='pt')

# %%
output = model(**encoded_input)

# %%
output
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-0.3174,  0.3400,  0.3435,  ...,  0.3912, -0.6910, -0.0082],
#          [-0.4749,  0.1843,  0.4281,  ...,  0.5589, -0.9643,  0.2218],
#          [-0.1665,  0.1171,  0.4705,  ...,  0.5523, -0.6137,  0.0169],
#          [-0.3730,  0.1922,  0.5142,  ...,  0.5004, -0.5163, -0.0759],
#          [-0.5133,  0.2897,  0.3450,  ...,  0.4531, -0.6372, -0.0427],
#          [-0.3210,  0.2438,  0.3431,  ...,  0.3513, -0.7284,  0.0310]]],
#        grad_fn=<NativeLayerNormBackward>), pooler_output=tensor([[ 2.3355e-01, -2.5574e-01,  3.4498e-01, -1.6866e-01, -1.3852e-01,
#          -1.9843e-01,  2.2111e-01,  1.5166e-01,  2.5818e-01,  4.1913e-02,
#          -6.5910e-01,  2.0494e-01,  2.0415e-01, -3.0485e-02,  5.5295e-01,
#          -5.6722e-02, -7.6894e-03,  2.0905e-01,  4.4752e-01, -4.7293e-01,
#          -5.6029e-01, -3.6637e-01, -3.3441e-01, -6.6017e-02,  3.9670e-01,
# ...
